# %% [markdown]
# 1-check whether a umber is positive

# %%
number=int(input("Enter the number"))
if number>0:
    print("number is positive")
# Out:
# number is positive

# %% [markdown]
# 2-check whether a number is divisible by 5

# %%
num=int(input("Enter the number"))
if num % 5==0:
    print("Number is divisible by 5")
# Out:
# Number is divisible by 5

# %% [markdown]
# 3-check whether a character is a vowel

# %%
ch=input("Enter a character: ")
if ch in "aeiouAEIOU":
    print("vowel")
# Out:
# vowel

# %% [markdown]
# 4-check even or odd

# %%
num=int(input("Enter a number: "))
if num % 2==0:
    print("Even")
else:
    print("odd")
# Out:
# odd

# %% [markdown]
# 5.check pass or fail

# %%
marks=int(input("Enter marks: "))
if marks >= 40:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %% [markdown]
# 6-check eligible to vote

# %%
age=int(input("Enter your age: "))
if age>=18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Eligible to vote

# %% [markdown]
# 7-find greater of two number

# %%
a=int(input("Enter the number: "))
b=int(input("Enter the number"))
if a>b:
    print("a is large")
else:
    print("b is large")
# Out:
# b is large

# %% [markdown]
# 8-find the largest of Three Number

# %%
a=int(input("Enter the number: "))
b=int(input("Enter the number: "))
c=int(input("Enter the number: "))
if a>=b and a>=c:
    print("Largest: ",a)
elif b>=a and b>=c:
    print("Largest: ",b)
else:
    print('largest: ',c)
# Out:
# largest:  6

# %% [markdown]
# 9.check positive,negative,or zero

# %%
num=int(input("Enter a number; "))
if num>0:
    print('Positive')
elif num<0:
    print("Negative")
else:
    print("zero")
# Out:
# Positive

# %% [markdown]
# 10.Grade Calculation
# 90–100 → A
# 75–89  → B
# 60–74  → C
# 40–59  → D
# Below 40 → F

# %%
marks=int(input("Enter the marks: "))
if marks>=90 and marks<=100:
    print("The grade is A")
elif marks>=75 and marks<=89:
    print("The grade is B")
elif marks>=60 and marks<=74:
    print("The grade is C")
elif marks>=40 and marks<=59:
    print("The grade is D")
else:
    print("Below 40 ->F")
# Out:
# The grade is B

# %% [markdown]
# 11.Electricity bill calculation
# 0-100 units  -> rs5/unit
# 101-200 units ->rs7/unit
# Above 200     ->    rs10/unit

# %%
units=int(input("Enter units; "))
print(units)
if units<=100:
    bill=units*5
elif units<=200:
    bill=unit*7
else:
    bill=unit*10
print("Electricity Bill: ",bill)
# Out:
# 99
# Electricity Bill:  495

# %% [markdown]
# 12.check number is positive and even

# %%
num=int(input("Enter a number"))
if num>0:
    if num %2==0:
        print("Positive Even number")
    else:
        print("Positive odd number")
else:
    print("Number is not positive")
# Out:
# Positive Even number

# %% [markdown]
# 13.check leap year

# %%
year=int(input("Enter the year"))
if year % 400==0:
    print("Leap year")
elif year % 100==0:
    print("Not Leap year")
elif year % 4==0:
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Leap year

# %% [markdown]
# 14.check number is prime

# %%
num=int(input("Enter the number: "))
if num<=1:
    print("Not Prime")
else:
    count=0
    for i in range(1,num+1):
        if num % i==0:
            count+=1
    if count==2:
        print("Prime Number")
    else:
        print("Not prime number")
# Out:
# Prime Number

# %% [markdown]
# 15.find the type of Triangle
# Given three sides, determine whether the triangle is:
#
# Equilateral
# Isosceles
# Scalene

# %%
a=int(input("Enter side 1: "))
b=int(input("enter the side 2: "))
c=int(input("Enter the side 3; "))

if a==b and b==c:
    print("Equilateral Triangle")
elif a==b or b==c or a==c:
    print("Isoscelss Triangle")
else:
    print("scalene Triangle")
# Out:
# Isoscelss Triangle

# %% [markdown]
# 16.Find the smallest of three number

# %%
a=int(input("enter the number: "))
b=int(input("Enter the number: "))
c=int(input("Enter the number: "))
print(a,b,c)
if a<b and a<c:
    print("a is small: ",a)
elif b<a and b<c:
    print("b is small: ",b)
else:
    print("c is small: ",c)
# Out:
# 1 2 3
# a is small:  1

# %% [markdown]
# 17.check whether a number is divisible by both 3 and 5

# %%
num=int(input("Enter the number: "))
print(num)
if num%3==0 and num%5==0:
    print("Number is divisible by both")
else:
    print("Number is divisible by not both")
# Out:
# 15
# Number is divisible by both

# %% [markdown]
# 18.calculate discount
#
# Amount >= 5000 → 20% discount
# Amount >= 3000 → 10% discount
# Otherwise      → No discount

# %%
amount=float(input("Enter the amount: "))
if amount>=5000:
    discount=amount*20/100
    final_amount=amount-discount
    print("Discount: ₹",discount)
    print("Final amount: ₹",final_amount)

elif amount>=3000:
        discount=amount*20/100
        final_amount=amount-discount
        print("Discount: ₹",discount)
        print("Final amount: ₹",final_amount)
else:
      print("No discount")
      print("Final amount= ₹",amount)
# Out:
# Discount: ₹ 900.0
# Final amount: ₹ 3600.0

# %% [markdown]
# 19.check whether a character is vowel or consonant

# %%
str=input("Enter the character: ")
vowel="aeiou"
if str.lower() in vowel:
    print("The give character is vowel: ",str)
else:
    print("The give character is consonant: ",str)
# Out:
# The give character is consonant:  T

# %% [markdown]
# 20.ATM withdrawal

# %%
balance = int(input("Enter your balance: "))
withdrawal = int(input("Enter withdrawal amount: "))

if balance >= withdrawal and withdrawal % 100 == 0:
    print("Transaction Successful")
else:
    print("Transaction Failed")
# Out:
# Transaction Successful
